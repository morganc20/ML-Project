# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import numpy as np
import sklearn

k_graph = DataFrame()

k_graph_from_excel = pd.read_excel(r'/Users/Morgan/Desktop/ENDG 319/CURE Fall 2021/StandardScaler.xlsx', usecols="A,B,C")

a = k_graph_from_excel.iloc[:,0]
b = k_graph_from_excel.iloc[:,1]
c = k_graph_from_excel.iloc[:,2]

# %%
fig, axs = plt.subplots(figsize =(10,2.5))
axs1 = plt.subplot2grid(shape= (1,1), loc = (0,0))

axs1.scatter (a,b, label='Training Dataset')
axs1.scatter (a,c, label='Test Dataset')
axs1.set_xlabel('K-value')
axs1.set_ylabel('Model Accuracy')
axs1.legend()
